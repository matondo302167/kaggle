# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Data sets/Medical_Cost_Personal_Datasets.csv"
data = pd.read_csv(path)
df = data.copy()

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.isna().sum()/df.shape[0]
# Out:
# age         0.0
# sex         0.0
# bmi         0.0
# children    0.0
# smoker      0.0
# region      0.0
# charges     0.0
# dtype: float64

# %%
df.dtypes.value_counts().plot.pie(); df.dtypes.value_counts()
# Out:
# object     3
# int64      2
# float64    2
# dtype: int64

# %%
cat_index = ['sex','smoker', 'region']
num_index = ['age', 'children','bmi','charges']

# %%
cat_data = df[cat_index]
num_data = df[num_index]

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
df.describe(include='all')
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663397     1.094918    NaN        NaN
# std       14.049960   NaN     6.098187     1.205493    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.296250     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.693750     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %% [markdown]
# ## **numerical data**

# %%
for col in num_data:
  plt.figure()
  sns.displot(num_data[col])

# %%
for col in df.select_dtypes('int64'):
  plt.figure()
  sns.displot(df[col])

# %%
for col in num_data:
  plt.figure()
  sns.boxplot(df[col])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# ## **categorical data**

# %%
for col in cat_data:
  plt.figure()
  cat_data[col].value_counts().plot(kind='bar')
  plt.title(col)

# %% [markdown]
# ## **Bivary relation**

# %%
for col in viral_columns:
    plt.figure()
    sns.heatmap(pd.crosstab(df['SARS-Cov-2 exam result'], df[col]), annot=True, fmt='d')
